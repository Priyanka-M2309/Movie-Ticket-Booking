# %%
# Movie ticket booking
from colorama import Fore, Back, Style

class Movie_ticket:
    def __init__(self):
        print(Fore.RED,Style.BRIGHT+"\t\t\t\t\t\t\t      FUN CINEMA")
        print(Fore.BLACK,Style.BRIGHT+"\t\t\t\t\t\t        www.funcinema_pvr.com")
        print(Fore.BLACK,Style.NORMAL+"\t\t\t\t\t\t\t   A PVR Experience")
    
    # Gadar Movie
    def gadar(self):
        print("_________________________________________________________________________________________________________________________________")
        print(Fore.RED,Style.BRIGHT+"\n\n Gadar 2: The Katha Continues")        
        print(Fore.BLACK,Style.NORMAL+"*****************************\n")
        print(Fore.BLACK,Style.BRIGHT+"Ratings:",Fore.BLACK,Style.NORMAL+"8.1/10","\t\t",Fore.BLACK,Style.BRIGHT+"Votes:",Fore.BLACK,Style.NORMAL+"299.2K Votes","\t\t",Fore.BLACK,Style.BRIGHT+"2D","\t\t",Fore.BLACK,Style.BRIGHT+"Hindi","\n")
        print(Fore.BLACK,Style.NORMAL+"2h 50m  •  Action  •  Drama  •  Period  •  UA  •  11 Aug, 2023")
        print(Fore.BLACK,Style.NORMAL+"---------------------------------------------------------------")
        print(Fore.BLACK,Style.BRIGHT+"About the movie\n",Fore.BLACK,Style.NORMAL+"")
        print("Gadar 2 brings back India`s most loved family of Tara, Sakeena and Jeete; 22 years after its predecessor. Set against the backdrop of Indo-Pakistan war of 1971, Tara Singh, once again, will face every enemy to protect the honor of country and family.")
        print("_________________________________________________________________________________________________________________________________")
        watch_trailer = input("\n\ndo you want to see trailer before booking (yes/no)")
        if watch_trailer == "yes" or watch_trailer == "Yes":
            import cv2 as cv
            capture = cv.VideoCapture("C:\\Users\\priya\\Desktop\\vdo.mp4")
            while True:
                isTrue,frame=capture.read()
                cv.imshow('video',frame)
    
                if cv.waitKey(20) & 0xff==ord('x'):
                    break
        
            capture.release()
            cv.destroyAllWindows()

        # Logic to book seat and ticket
        shows_at = ["9:00 AM","12:20 PM","4:00 PM","7:20 PM","10:45 PM"]
        print("\nTime Slot:", shows_at)
        sel_time = input("\nselect the time at which you want to book(Please give space befor writing (AM/PM)):")
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            seat = ["EXECUTIVE","CLUB","ROYAL","ROYAL RECLINER","ROYAL EXECUTIVE RECLINER"]
            seat_price = [200,220,300,350,450]
            table_ = {"SEAT CLASS":seat,"PRICE":seat_price}
            import pandas as pd
            df = pd.DataFrame(table_)
            print("\n\n Gadar 2: The Katha Continues")
            print(df)
            ticket_book = []
            while seat:
                print("\n")
                seat_cls = int(input("enter the seat class no. you want to book:"))
                no_of_seat = int(input("Enter the no. of seat you want to book"))
                seat_price = table_["PRICE"][seat_cls]
                tickets = seat_price*no_of_seat
                ticket_book.append(tickets)
                break
                
            total = sum(ticket_book)
            tax = (sum(ticket_book)*0.18)
            grand_total = total + tax
            print(Fore.BLACK,Style.NORMAL+"\n---------------------------------------------------------------\n")
            print(Fore.BLACK,Style.BRIGHT+"Your Total Bill is --",Fore.BLACK,Style.NORMAL+"")
            print("Amount:",total,"Rupees")
            print("Taxes:",tax)
            print("Total amount:",grand_total,"Rupees")
            print("\nTaking you to the payment page.\n\n")
            payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")

            if payment=="paytm" or payment=="Paytm":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="phonepe" or payment=="Phonepe":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey() 
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
            else:
                print(Fore.RED,Style.BRIGHT+" Wrong payment option choosen",Fore.BLACK,Style.NORMAL+"")
            import random
            book=random.randint(1001,100000) 
            print(Fore.BLACK,Style.NORMAL+"------------------------------------------------------------------------------------")
            print(Fore.RED,Style.BRIGHT+"\t\t\t\t * BOOKING DETAILS:\n")
            print(Fore.BLACK,Style.BRIGHT+"Booking no.","\t",Fore.BLACK,Style.NORMAL+"",book) # print("Booking no.:",book)
            print(Fore.BLACK,Style.BRIGHT+"Movie Name","\t",Fore.BLACK,Style.NORMAL+"Gadar 2: The Katha Continues")
            print(Fore.BLACK,Style.BRIGHT+"Ticket Booked","",Fore.BLACK,Style.NORMAL+"",no_of_seat)
            print(Fore.BLACK,Style.BRIGHT+"Time","\t\t",Fore.BLACK,Style.NORMAL+"",sel_time)
            print(Fore.BLACK,Style.BRIGHT+"Screen","\t",Fore.BLACK,Style.NORMAL+"NA-3")
            print(Fore.BLACK,Style.BRIGHT+"Payment Type","\t",Fore.BLACK,Style.NORMAL+"",payment)
        else:
            print("No Show was availiable at this time")
        
        # Booking for food
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            pre_food = input("\n\nDo you want to pre-book your food (yes/no)")
            if pre_food=="yes" or pre_food=="Yes":
                food = ["OTC Pizza","Popcorn","Pepsi","Sprite","Mountain Due","Burger","Cheese Popcorn"]
                price = [345,220,80,80,80,140,320]
                food_table = {"ITEM":food,"Price":price}
                import pandas as pd
                df=pd.DataFrame(food_table)
                print("\n\n FOOD MENU")
                print(df)
                food_include=[]
                repeat = True
                while repeat:
                    fd_item = int(input("\nEnter the code of the food you want to order:"))
                    qty = int(input("How much Quatity you want to order:"))
                    price = food_table["Price"][fd_item]
                    total_price = qty*price
                    food_include.append(total_price)
                    repeat = input("Do you want to order more?(yes/no)")
                    if repeat=="no":
                        print("\nThankyou! please check the amount before processing with payment\n")
                        break
                
                total_ = sum(food_include)
                tax = (total_*0.05)
                grand_total = total_ + tax
                print("\n------------------------------------------------------------------------------\n")
                print("\t\t\t\t * BOOKING DETAILS:\n")
                print("Amount:",total_,"Rupees")
                print("Tax:5%")
                print("Total Amount:",grand_total,"Rupees")
                print("\nTaking you to the payment page.\n")
                payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")
    
                if payment=="paytm" or payment=="Paytm":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="phonepe" or payment=="Phonepe":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey() 
                    
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                else:
                    print("Sorry! Wrong payment option choosen")
            else:
                print("Thankyou! Enjoy the Show!")

    # Fukrey Movie
    def fukrey(self):
        print("_________________________________________________________________________________________________________________________________")
        print(Fore.RED,Style.BRIGHT+"\n\n Fukrey 3")        
        print(Fore.BLACK,Style.NORMAL+"**************\n")
        print(Fore.BLACK,Style.BRIGHT+"Ratings:",Fore.BLACK,Style.NORMAL+"7.2/10","\t\t",Fore.BLACK,Style.BRIGHT+"Votes:",Fore.BLACK,Style.NORMAL+"31.4K Votes","\t\t",Fore.BLACK,Style.BRIGHT+"2D","\t\t",Fore.BLACK,Style.BRIGHT+"Hindi","\n")
        print(Fore.BLACK,Style.NORMAL+"2h 30m  •  Comedy  •  UA  •  28 Sep, 2023")
        print(Fore.BLACK,Style.NORMAL+"---------------------------------------------------------------")
        print(Fore.BLACK,Style.BRIGHT+"About the movie\n",Fore.BLACK,Style.NORMAL+"")
        print("Iss baar hoga chamatkaar, straight from Jamnapaar! The Fukras are back with 3X more fukrapanti")
        print("_________________________________________________________________________________________________________________________________")
        watch_trailer = input("\n\ndo you want to see trailer before booking (yes/no)")
        if watch_trailer == "yes" or watch_trailer == "Yes":
            import cv2 as cv
            capture = cv.VideoCapture("C:\\Users\\priya\\Desktop\\vdo.mp4")
            while True:
                isTrue,frame=capture.read()
                cv.imshow('video',frame)
    
                if cv.waitKey(20) & 0xff==ord('x'):
                    break
        
            capture.release()
            cv.destroyAllWindows()

        # Logic to book seat and ticket
        shows_at = ["9:00 AM","12:20 PM","4:00 PM","7:20 PM","10:45 PM"]
        print("\nTime Slot:", shows_at)
        sel_time = input("\nselect the time at which you want to book(Please give space befor writing (AM/PM)):")
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            seat = ["EXECUTIVE","CLUB","ROYAL","ROYAL RECLINER","ROYAL EXECUTIVE RECLINER"]
            seat_price = [200,220,300,350,450]
            table_ = {"SEAT CLASS":seat,"PRICE":seat_price}
            import pandas as pd
            df = pd.DataFrame(table_)
            print("\n\n Fukrey 3")
            print(df)
            ticket_book = []
            while seat:
                print("\n")
                seat_cls = int(input("enter the seat class no. you want to book:"))
                no_of_seat = int(input("Enter the no. of seat you want to book"))
                seat_price = table_["PRICE"][seat_cls]
                tickets = seat_price*no_of_seat
                ticket_book.append(tickets)
                break
                
            total = sum(ticket_book)
            tax = (sum(ticket_book)*0.18)
            grand_total = total + tax
            print(Fore.BLACK,Style.NORMAL+"\n---------------------------------------------------------------\n")
            print(Fore.BLACK,Style.BRIGHT+"Your Total Bill is --",Fore.BLACK,Style.NORMAL+"")
            print("Amount:",total,"Rupees")
            print("Taxes:",tax)
            print("Total amount:",grand_total,"Rupees")
            print("\nTaking you to the payment page.\n\n")
            payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")

            if payment=="paytm" or payment=="Paytm":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="phonepe" or payment=="Phonepe":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey() 
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
            else:
                print(Fore.RED,Style.BRIGHT+" Wrong payment option choosen",Fore.BLACK,Style.NORMAL+"")
            import random
            book=random.randint(1001,100000) 
            print(Fore.BLACK,Style.NORMAL+"------------------------------------------------------------------------------------")
            print(Fore.RED,Style.BRIGHT+"\t\t\t\t * BOOKING DETAILS:\n")
            print(Fore.BLACK,Style.BRIGHT+"Booking no.","\t",Fore.BLACK,Style.NORMAL+"",book)
            print(Fore.BLACK,Style.BRIGHT+"Movie Name","\t",Fore.BLACK,Style.NORMAL+"Fukrey 3")
            print(Fore.BLACK,Style.BRIGHT+"Ticket Booked","",Fore.BLACK,Style.NORMAL+"",no_of_seat)
            print(Fore.BLACK,Style.BRIGHT+"Time","\t\t",Fore.BLACK,Style.NORMAL+"",sel_time)
            print(Fore.BLACK,Style.BRIGHT+"Screen","\t",Fore.BLACK,Style.NORMAL+"NA-2")
            print(Fore.BLACK,Style.BRIGHT+"Payment Type","\t",Fore.BLACK,Style.NORMAL+"",payment)
        else:
            print("No Show was availiable at this time")
        
        # Booking for food
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            pre_food = input("\n\nDo you want to pre-book your food (yes/no)")
            if pre_food=="yes" or pre_food=="Yes":
                food = ["OTC Pizza","Popcorn","Pepsi","Sprite","Mountain Due","Burger","Cheese Popcorn"]
                price = [345,220,80,80,80,140,320]
                food_table = {"ITEM":food,"Price":price}
                import pandas as pd
                df=pd.DataFrame(food_table)
                print("\n\n FOOD MENU")
                print(df)
                food_include=[]
                repeat = True
                while repeat:
                    fd_item = int(input("\nEnter the code of the food you want to order:"))
                    qty = int(input("How much Quatity you want to order:"))
                    price = food_table["Price"][fd_item]
                    total_price = qty*price
                    food_include.append(total_price)
                    repeat = input("Do you want to order more?(yes/no)")
                    if repeat=="no":
                        print("\nThankyou! please check the amount before processing with payment\n")
                        break
                
                total_ = sum(food_include)
                tax = (total_*0.05)
                grand_total = total_ + tax
                print("\n------------------------------------------------------------------------------\n")
                print("\t\t\t\t * BOOKING DETAILS:\n")
                print("Amount:",total_,"Rupees")
                print("Tax:5%")
                print("Total Amount:",grand_total,"Rupees")
                print("\nTaking you to the payment page.\n")
                payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")
    
                if payment=="paytm" or payment=="Paytm":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="phonepe" or payment=="Phonepe":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey() 
                    
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                else:
                    print("Sorry! Wrong payment option choosen")
            else:
                print("Thankyou! Enjoy the Show!")
        
    # Chandramukhi 2 Movie
    def chandramukhi(self):
        print("_________________________________________________________________________________________________________________________________")
        print(Fore.RED,Style.BRIGHT+"\n\n Chandramukhi 2")        
        print(Fore.BLACK,Style.NORMAL+"**************\n")
        print(Fore.BLACK,Style.BRIGHT+"Ratings:",Fore.BLACK,Style.NORMAL+"5.4/10","\t\t",Fore.BLACK,Style.BRIGHT+"Votes:",Fore.BLACK,Style.NORMAL+"26.8K Votes","\t\t",Fore.BLACK,Style.BRIGHT+"2D","\t\t",Fore.BLACK,Style.BRIGHT+"Hindi","\n")
        print(Fore.BLACK,Style.NORMAL+"2h 38m  •  Comedy, Horror  •  UA  •  28 Sep, 2023")
        print(Fore.BLACK,Style.NORMAL+"---------------------------------------------------------------")
        print(Fore.BLACK,Style.BRIGHT+"About the movie\n",Fore.BLACK,Style.NORMAL+"")
        print("A psychiatrist puts his life in danger to solve a case involving a woman suffering from dissociative identity disorder.")
        print("_________________________________________________________________________________________________________________________________")
        watch_trailer = input("\n\ndo you want to see trailer before booking (yes/no)")
        if watch_trailer == "yes" or watch_trailer == "Yes":
            import cv2 as cv
            capture = cv.VideoCapture("C:\\Users\\priya\\Desktop\\vdo.mp4")
            while True:
                isTrue,frame=capture.read()
                cv.imshow('video',frame)
    
                if cv.waitKey(20) & 0xff==ord('x'):
                    break
        
            capture.release()
            cv.destroyAllWindows()

        # Logic to book seat and ticket
        shows_at = ["9:00 AM","12:20 PM","4:00 PM","7:20 PM","10:45 PM"]
        print("\nTime Slot:", shows_at)
        sel_time = input("\nselect the time at which you want to book(Please give space befor writing (AM/PM)):")
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            seat = ["EXECUTIVE","CLUB","ROYAL","ROYAL RECLINER","ROYAL EXECUTIVE RECLINER"]
            seat_price = [200,220,300,350,450]
            table_ = {"SEAT CLASS":seat,"PRICE":seat_price}
            import pandas as pd
            df = pd.DataFrame(table_)
            print("\n\n Chandramukhi 2")
            print(df)
            ticket_book = []
            while seat:
                print("\n")
                seat_cls = int(input("enter the seat class no. you want to book:"))
                no_of_seat = int(input("Enter the no. of seat you want to book"))
                seat_price = table_["PRICE"][seat_cls]
                tickets = seat_price*no_of_seat
                ticket_book.append(tickets)
                break
                
            total = sum(ticket_book)
            tax = (sum(ticket_book)*0.18)
            grand_total = total + tax
            print(Fore.BLACK,Style.NORMAL+"\n---------------------------------------------------------------\n")
            print(Fore.BLACK,Style.BRIGHT+"Your Total Bill is --",Fore.BLACK,Style.NORMAL+"")
            print("Amount:",total,"Rupees")
            print("Taxes:",tax)
            print("Total amount:",grand_total,"Rupees")
            print("\nTaking you to the payment page.\n\n")
            payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")

            if payment=="paytm" or payment=="Paytm":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="phonepe" or payment=="Phonepe":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey() 
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
            else:
                print(Fore.RED,Style.BRIGHT+" Wrong payment option choosen",Fore.BLACK,Style.NORMAL+"")
            import random
            book=random.randint(1001,100000) 
            print(Fore.BLACK,Style.NORMAL+"------------------------------------------------------------------------------------")
            print(Fore.RED,Style.BRIGHT+"\t\t\t\t * BOOKING DETAILS:\n")
            print(Fore.BLACK,Style.BRIGHT+"Booking no.","\t",Fore.BLACK,Style.NORMAL+"",book)
            print(Fore.BLACK,Style.BRIGHT+"Movie Name","\t",Fore.BLACK,Style.NORMAL+"Chandramukhi 2")
            print(Fore.BLACK,Style.BRIGHT+"Ticket Booked","",Fore.BLACK,Style.NORMAL+"",no_of_seat)
            print(Fore.BLACK,Style.BRIGHT+"Time","\t\t",Fore.BLACK,Style.NORMAL+"",sel_time)
            print(Fore.BLACK,Style.BRIGHT+"Screen","\t",Fore.BLACK,Style.NORMAL+"NA-1")
            print(Fore.BLACK,Style.BRIGHT+"Payment Type","\t",Fore.BLACK,Style.NORMAL+"",payment)
        else:
            print("No Show was availiable at this time")
        
        # Booking for food
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            pre_food = input("\n\nDo you want to pre-book your food (yes/no)")
            if pre_food=="yes" or pre_food=="Yes":
                food = ["OTC Pizza","Popcorn","Pepsi","Sprite","Mountain Due","Burger","Cheese Popcorn"]
                price = [345,220,80,80,80,140,320]
                food_table = {"ITEM":food,"Price":price}
                import pandas as pd
                df=pd.DataFrame(food_table)
                print("\n\n FOOD MENU")
                print(df)
                food_include=[]
                repeat = True
                while repeat:
                    fd_item = int(input("\nEnter the code of the food you want to order:"))
                    qty = int(input("How much Quatity you want to order:"))
                    price = food_table["Price"][fd_item]
                    total_price = qty*price
                    food_include.append(total_price)
                    repeat = input("Do you want to order more?(yes/no)")
                    if repeat=="no":
                        print("\nThankyou! please check the amount before processing with payment\n")
                        break
                
                total_ = sum(food_include)
                tax = (total_*0.05)
                grand_total = total_ + tax
                print("\n------------------------------------------------------------------------------\n")
                print("\t\t\t\t * BOOKING DETAILS:\n")
                print("Amount:",total_,"Rupees")
                print("Tax:5%")
                print("Total Amount:",grand_total,"Rupees")
                print("\nTaking you to the payment page.\n")
                payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")
    
                if payment=="paytm" or payment=="Paytm":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="phonepe" or payment=="Phonepe":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey() 
                    
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                else:
                    print("Sorry! Wrong payment option choosen")
            else:
                print("Thankyou! Enjoy the Show!")

    # The Nun 2 Movie
    def nun(self):
        print("_________________________________________________________________________________________________________________________________")
        print(Fore.RED,Style.BRIGHT+"\n\n The Nun 2")        
        print(Fore.BLACK,Style.NORMAL+"************\n")
        print(Fore.BLACK,Style.BRIGHT+"Ratings:",Fore.BLACK,Style.NORMAL+"6.8/10","\t\t",Fore.BLACK,Style.BRIGHT+"Votes:",Fore.BLACK,Style.NORMAL+"51.2K Votes","\t\t",Fore.BLACK,Style.BRIGHT+"2D, ICE, 4DX, MX4D, 2D SCREEN X","\t\t",Fore.BLACK,Style.BRIGHT+"English, Hindi, Tamil, Telugu","\n")
        print(Fore.BLACK,Style.NORMAL+"1h 51m  •  Mystery, Thriller, Horror  •  A  •  7 Sep, 2023")
        print(Fore.BLACK,Style.NORMAL+"---------------------------------------------------------------")
        print(Fore.BLACK,Style.BRIGHT+"About the movie\n",Fore.BLACK,Style.NORMAL+"")
        print("The sequel to the worldwide smash hit follows Sister Irene as she once again comes face-to-face with Valak, the demon nun.")
        print("_________________________________________________________________________________________________________________________________")
        watch_trailer = input("\n\ndo you want to see trailer before booking (yes/no)")
        if watch_trailer == "yes" or watch_trailer == "Yes":
            import cv2 as cv
            capture = cv.VideoCapture("C:\\Users\\priya\\Desktop\\vdo.mp4")
            while True:
                isTrue,frame=capture.read()
                cv.imshow('video',frame)
    
                if cv.waitKey(20) & 0xff==ord('x'):
                    break
        
            capture.release()
            cv.destroyAllWindows()

        # Logic to book seat and ticket
        shows_at = ["9:00 AM","12:20 PM","4:00 PM","7:20 PM","10:45 PM"]
        print("\nTime Slot:", shows_at)
        sel_time = input("\nselect the time at which you want to book(Please give space befor writing (AM/PM)):")
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            seat = ["EXECUTIVE","CLUB","ROYAL","ROYAL RECLINER","ROYAL EXECUTIVE RECLINER"]
            seat_price = [200,220,300,350,450]
            table_ = {"SEAT CLASS":seat,"PRICE":seat_price}
            import pandas as pd
            df = pd.DataFrame(table_)
            print("\n\n The Nun 2")
            print(df)
            ticket_book = []
            while seat:
                print("\n")
                seat_cls = int(input("enter the seat class no. you want to book:"))
                no_of_seat = int(input("Enter the no. of seat you want to book"))
                seat_price = table_["PRICE"][seat_cls]
                tickets = seat_price*no_of_seat
                ticket_book.append(tickets)
                break
                
            total = sum(ticket_book)
            tax = (sum(ticket_book)*0.18)
            grand_total = total + tax
            print(Fore.BLACK,Style.NORMAL+"\n---------------------------------------------------------------\n")
            print(Fore.BLACK,Style.BRIGHT+"Your Total Bill is --",Fore.BLACK,Style.NORMAL+"")
            print("Amount:",total,"Rupees")
            print("Taxes:",tax)
            print("Total amount:",grand_total,"Rupees")
            print("\nTaking you to the payment page.\n\n")
            payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")

            if payment=="paytm" or payment=="Paytm":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="phonepe" or payment=="Phonepe":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey() 
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
            else:
                print(Fore.RED,Style.BRIGHT+" Wrong payment option choosen",Fore.BLACK,Style.NORMAL+"")
            import random
            book=random.randint(1001,100000) 
            print(Fore.BLACK,Style.NORMAL+"------------------------------------------------------------------------------------")
            print(Fore.RED,Style.BRIGHT+"\t\t\t\t * BOOKING DETAILS:\n")
            print(Fore.BLACK,Style.BRIGHT+"Booking no.","\t",Fore.BLACK,Style.NORMAL+"",book)
            print(Fore.BLACK,Style.BRIGHT+"Movie Name","\t",Fore.BLACK,Style.NORMAL+"The Nun 2")
            print(Fore.BLACK,Style.BRIGHT+"Ticket Booked","",Fore.BLACK,Style.NORMAL+"",no_of_seat)
            print(Fore.BLACK,Style.BRIGHT+"Time","\t\t",Fore.BLACK,Style.NORMAL+"",sel_time)
            print(Fore.BLACK,Style.BRIGHT+"Screen","\t",Fore.BLACK,Style.NORMAL+"NA-2")
            print(Fore.BLACK,Style.BRIGHT+"Payment Type","\t",Fore.BLACK,Style.NORMAL+"",payment)
        else:
            print("No Show was availiable at this time")
        
        # Booking for food
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            pre_food = input("\n\nDo you want to pre-book your food (yes/no)")
            if pre_food=="yes" or pre_food=="Yes":
                food = ["OTC Pizza","Popcorn","Pepsi","Sprite","Mountain Due","Burger","Cheese Popcorn"]
                price = [345,220,80,80,80,140,320]
                food_table = {"ITEM":food,"Price":price}
                import pandas as pd
                df=pd.DataFrame(food_table)
                print("\n\n FOOD MENU")
                print(df)
                food_include=[]
                repeat = True
                while repeat:
                    fd_item = int(input("\nEnter the code of the food you want to order:"))
                    qty = int(input("How much Quatity you want to order:"))
                    price = food_table["Price"][fd_item]
                    total_price = qty*price
                    food_include.append(total_price)
                    repeat = input("Do you want to order more?(yes/no)")
                    if repeat=="no":
                        print("\nThankyou! please check the amount before processing with payment\n")
                        break
                
                total_ = sum(food_include)
                tax = (total_*0.05)
                grand_total = total_ + tax
                print("\n------------------------------------------------------------------------------\n")
                print("\t\t\t\t * BOOKING DETAILS:\n")
                print("Amount:",total_,"Rupees")
                print("Tax:5%")
                print("Total Amount:",grand_total,"Rupees")
                print("\nTaking you to the payment page.\n")
                payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")
    
                if payment=="paytm" or payment=="Paytm":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="phonepe" or payment=="Phonepe":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey() 
                    
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                else:
                    print("Sorry! Wrong payment option choosen")
            else:
                print("Thankyou! Enjoy the Show!")

    # Saw X Movie
    def saw(self):
        print("_________________________________________________________________________________________________________________________________")
        print(Fore.RED,Style.BRIGHT+"\n\n Saw X")        
        print(Fore.BLACK,Style.NORMAL+"**********\n")
        print(Fore.BLACK,Style.BRIGHT+"Ratings:",Fore.BLACK,Style.NORMAL+"8.2/10","\t\t",Fore.BLACK,Style.BRIGHT+"Votes:",Fore.BLACK,Style.NORMAL+"1.4K Votes","\t\t",Fore.BLACK,Style.BRIGHT+"2D, ICE, 4DX","\t\t",Fore.BLACK,Style.BRIGHT+"English","\n")
        print(Fore.BLACK,Style.NORMAL+"1h 59m  •  Horror, Thriller  •  A  •  28 Sep, 2023")
        print(Fore.BLACK,Style.NORMAL+"---------------------------------------------------------------")
        print(Fore.BLACK,Style.BRIGHT+"About the movie\n",Fore.BLACK,Style.NORMAL+"")
        print("John Kramer (Tobin Bell) is back with the most disturbing installment of the SAW franchise that explores the untold chapter of Jigsaw`s most personal game.")
        print("_________________________________________________________________________________________________________________________________")
        watch_trailer = input("\n\ndo you want to see trailer before booking (yes/no)")
        if watch_trailer == "yes" or watch_trailer == "Yes":
            import cv2 as cv
            capture = cv.VideoCapture("C:\\Users\\priya\\Desktop\\vdo.mp4")
            while True:
                isTrue,frame=capture.read()
                cv.imshow('video',frame)
    
                if cv.waitKey(20) & 0xff==ord('x'):
                    break
        
            capture.release()
            cv.destroyAllWindows()

        # Logic to book seat and ticket
        shows_at = ["9:00 AM","12:20 PM","4:00 PM","7:20 PM","10:45 PM"]
        print("\nTime Slot:", shows_at)
        sel_time = input("\nselect the time at which you want to book(Please give space befor writing (AM/PM)):")
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            seat = ["EXECUTIVE","CLUB","ROYAL","ROYAL RECLINER","ROYAL EXECUTIVE RECLINER"]
            seat_price = [200,220,300,350,450]
            table_ = {"SEAT CLASS":seat,"PRICE":seat_price}
            import pandas as pd
            df = pd.DataFrame(table_)
            print("\n\n Saw X")
            print(df)
            ticket_book = []
            while seat:
                print("\n")
                seat_cls = int(input("enter the seat class no. you want to book:"))
                no_of_seat = int(input("Enter the no. of seat you want to book"))
                seat_price = table_["PRICE"][seat_cls]
                tickets = seat_price*no_of_seat
                ticket_book.append(tickets)
                break
                
            total = sum(ticket_book)
            tax = (sum(ticket_book)*0.18)
            grand_total = total + tax
            print(Fore.BLACK,Style.NORMAL+"\n---------------------------------------------------------------\n")
            print(Fore.BLACK,Style.BRIGHT+"Your Total Bill is --",Fore.BLACK,Style.NORMAL+"")
            print("Amount:",total,"Rupees")
            print("Taxes:",tax)
            print("Total amount:",grand_total,"Rupees")
            print("\nTaking you to the payment page.\n\n")
            payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")
            if payment=="paytm" or payment=="Paytm":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="phonepe" or payment=="Phonepe":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey() 
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
            else:
                print(Fore.RED,Style.BRIGHT+" Wrong payment option choosen",Fore.BLACK,Style.NORMAL+"")
                
            import random
            book=random.randint(1001,100000) 
            print(Fore.BLACK,Style.NORMAL+"------------------------------------------------------------------------------------")
            print(Fore.RED,Style.BRIGHT+"\t\t\t\t * BOOKING DETAILS:\n")
            print(Fore.BLACK,Style.BRIGHT+"Booking no.","\t",Fore.BLACK,Style.NORMAL+"",book)
            print(Fore.BLACK,Style.BRIGHT+"Movie Name","\t",Fore.BLACK,Style.NORMAL+"Saw X")
            print(Fore.BLACK,Style.BRIGHT+"Ticket Booked","",Fore.BLACK,Style.NORMAL+"",no_of_seat)
            print(Fore.BLACK,Style.BRIGHT+"Time","\t\t",Fore.BLACK,Style.NORMAL+"",sel_time)
            print(Fore.BLACK,Style.BRIGHT+"Screen","\t",Fore.BLACK,Style.NORMAL+"NA-1")
            print(Fore.BLACK,Style.BRIGHT+"Payment Type","\t",Fore.BLACK,Style.NORMAL+"",payment)
        else:
            print("No Show was availiable at this time")
        
        # Booking for food
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            pre_food = input("\n\nDo you want to pre-book your food (yes/no)")
            if pre_food=="yes" or pre_food=="Yes":
                food = ["OTC Pizza","Popcorn","Pepsi","Sprite","Mountain Due","Burger","Cheese Popcorn"]
                price = [345,220,80,80,80,140,320]
                food_table = {"ITEM":food,"Price":price}
                import pandas as pd
                df=pd.DataFrame(food_table)
                print("\n\n FOOD MENU")
                print(df)
                food_include=[]
                repeat = True
                while repeat:
                    fd_item = int(input("\nEnter the code of the food you want to order:"))
                    qty = int(input("How much Quatity you want to order:"))
                    price = food_table["Price"][fd_item]
                    total_price = qty*price
                    food_include.append(total_price)
                    repeat = input("Do you want to order more?(yes/no)")
                    if repeat=="no":
                        print("\nThankyou! please check the amount before processing with payment\n")
                        break
                
                total_ = sum(food_include)
                tax = (total_*0.05)
                grand_total = total_ + tax
                print("\n------------------------------------------------------------------------------\n")
                print("\t\t\t\t * BOOKING DETAILS:\n")
                print("Amount:",total_,"Rupees")
                print("Tax:5%")
                print("Total Amount:",grand_total,"Rupees")
                print("\nTaking you to the payment page.\n")
                payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")
    
                if payment=="paytm" or payment=="Paytm":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="phonepe" or payment=="Phonepe":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey() 
                    
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                else:
                    print("Sorry! Wrong payment option choosen")
            else:
                print("Thankyou! Enjoy the Show!")

    # Dream girl 2 Movie
    def dream_girl(self):
        print("_________________________________________________________________________________________________________________________________")
        print(Fore.RED,Style.BRIGHT+"\n\n Dream Girl 2")        
        print(Fore.BLACK,Style.NORMAL+"**********\n")
        print(Fore.BLACK,Style.BRIGHT+"Ratings:",Fore.BLACK,Style.NORMAL+"7.7/10","\t\t",Fore.BLACK,Style.BRIGHT+"Votes:",Fore.BLACK,Style.NORMAL+"80.1K Votes","\t\t",Fore.BLACK,Style.BRIGHT+"2D","\t\t",Fore.BLACK,Style.BRIGHT+"Hindi","\n")
        print(Fore.BLACK,Style.NORMAL+"2h 13m  •  Comedy, Drama, Romantic  •  UA  •  25 Aug, 2023")
        print(Fore.BLACK,Style.NORMAL+"---------------------------------------------------------------")
        print(Fore.BLACK,Style.BRIGHT+"About the movie\n",Fore.BLACK,Style.NORMAL+"")
        print("Karam, a small-town boy from Mathura, is struggling to pay his father`s debt, who has borrowed money from nearly everyone on the planet. On the other hand, he is deeply in love with Pari, whose father has kept conditions to marry her. To make ends meet, Karam dons as Pooja, which creates wild chaos and a comedy of errors.")
        print("_________________________________________________________________________________________________________________________________")
        watch_trailer = input("\n\ndo you want to see trailer before booking (yes/no)")
        if watch_trailer == "yes" or watch_trailer == "Yes":
            import cv2 as cv
            capture = cv.VideoCapture("C:\\Users\\priya\\Desktop\\vdo.mp4")
            while True:
                isTrue,frame=capture.read()
                cv.imshow('video',frame)
    
                if cv.waitKey(20) & 0xff==ord('x'):
                    break
        
            capture.release()
            cv.destroyAllWindows()

        # Logic to book seat and ticket
        shows_at = ["9:00 AM","12:20 PM","4:00 PM","7:20 PM","10:45 PM"]
        print("\nTime Slot:", shows_at)
        sel_time = input("\nselect the time at which you want to book(Please give space befor writing (AM/PM)):")
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            seat = ["EXECUTIVE","CLUB","ROYAL","ROYAL RECLINER","ROYAL EXECUTIVE RECLINER"]
            seat_price = [200,220,300,350,450]
            table_ = {"SEAT CLASS":seat,"PRICE":seat_price}
            import pandas as pd
            df = pd.DataFrame(table_)
            print("\n\n Dream Girl 2")
            print(df)
            ticket_book = []
            while seat:
                print("\n")
                seat_cls = int(input("enter the seat class no. you want to book:"))
                no_of_seat = int(input("Enter the no. of seat you want to book"))
                seat_price = table_["PRICE"][seat_cls]
                tickets = seat_price*no_of_seat
                ticket_book.append(tickets)
                break
                
            total = sum(ticket_book)
            tax = (sum(ticket_book)*0.18)
            grand_total = total + tax
            print(Fore.BLACK,Style.NORMAL+"\n---------------------------------------------------------------\n")
            print(Fore.BLACK,Style.BRIGHT+"Your Total Bill is --",Fore.BLACK,Style.NORMAL+"")
            print("Amount:",total,"Rupees")
            print("Taxes:",tax)
            print("Total amount:",grand_total,"Rupees")
            print("\nTaking you to the payment page.\n\n")
            payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")

            if payment=="paytm" or payment=="Paytm":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="phonepe" or payment=="Phonepe":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey()
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
                
            elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                import cv2 as cv
                img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                cv.imshow("payment",img)
                cv.waitKey() 
                print(Fore.GREEN,Style.BRIGHT+"\nYour Booking Was Confirmed.Thank you!",Fore.BLACK,Style.NORMAL+"")
            else:
                print(Fore.RED,Style.BRIGHT+" Wrong payment option choosen",Fore.BLACK,Style.NORMAL+"")
            import random
            book=random.randint(1001,100000) 
            print(Fore.BLACK,Style.NORMAL+"------------------------------------------------------------------------------------")
            print(Fore.RED,Style.BRIGHT+"\t\t\t\t * BOOKING DETAILS:\n")
            print(Fore.BLACK,Style.BRIGHT+"Booking no.","\t",Fore.BLACK,Style.NORMAL+"",book)
            print(Fore.BLACK,Style.BRIGHT+"Movie Name","\t",Fore.BLACK,Style.NORMAL+"Dream Girl 2")
            print(Fore.BLACK,Style.BRIGHT+"Ticket Booked","",Fore.BLACK,Style.NORMAL+"",no_of_seat)
            print(Fore.BLACK,Style.BRIGHT+"Time","\t\t",Fore.BLACK,Style.NORMAL+"",sel_time)
            print(Fore.BLACK,Style.BRIGHT+"Screen","\t",Fore.BLACK,Style.NORMAL+"NA-4")
            print(Fore.BLACK,Style.BRIGHT+"Payment Type","\t",Fore.BLACK,Style.NORMAL+"",payment)
        else:
            print(" No Show was availiable at this time")
        # Booking for food
        if(sel_time == "9:00 AM" or sel_time == "9:00 am" or sel_time == "9 am" or sel_time == "12:20 PM" or sel_time == "12:20 pm" or sel_time == "4:00 PM" or sel_time == "4:00 pm" or sel_time == "7:20 PM" or sel_time == "7:20 pm" or sel_time == "10:45 PM" or sel_time == "10:45 pm"):
            pre_food = input("\n\nDo you want to pre-book your food (yes/no)")
            if pre_food=="yes" or pre_food=="Yes":
                food = ["OTC Pizza","Popcorn","Pepsi","Sprite","Mountain Due","Burger","Cheese Popcorn"]
                price = [345,220,80,80,80,140,320]
                food_table = {"ITEM":food,"Price":price}
                import pandas as pd
                df=pd.DataFrame(food_table)
                print("\n\n FOOD MENU")
                print(df)
                food_include=[]
                repeat = True
                while repeat:
                    fd_item = int(input("\nEnter the code of the food you want to order:"))
                    qty = int(input("How much Quatity you want to order:"))
                    price = food_table["Price"][fd_item]
                    total_price = qty*price
                    food_include.append(total_price)
                    repeat = input("Do you want to order more?(yes/no)")
                    if repeat=="no":
                        print("\nThankyou! please check the amount before processing with payment\n")
                        break
                
                total_ = sum(food_include)
                tax = (total_*0.05)
                grand_total = total_ + tax
                print("\n------------------------------------------------------------------------------\n")
                print("\t\t\t\t * BOOKING DETAILS:\n")
                print("Amount:",total_,"Rupees")
                print("Tax:5%")
                print("Total Amount:",grand_total,"Rupees")
                print("\nTaking you to the payment page.\n")
                payment=input("Enter the name of payment app from given app by which you want to pay \n1)Paytm \n2)Phonepe \n3)GooglePay \nNOTE-> Please do not close the next window till you completed the payment.\n")
    
                if payment=="paytm" or payment=="Paytm":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="phonepe" or payment=="Phonepe":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey()
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                    
                elif payment=="GooglePay" or payment=="googlepay" or payment=="Googlepay":
                    import cv2 as cv
                    img=cv.imread("C:\\Users\\priya\\Desktop\\IIHT_python_Sep\\payment.jpeg")
                    cv.imshow("payment",img)
                    cv.waitKey() 
                    
                    print("\nThank you! Your Booking for Food is done. Please take your food reciept\n")
                else:
                    print("Sorry! Wrong payment option choosen")
            else:
                print("Thankyou! Enjoy the Show!")

    
obj = Movie_ticket()

cities_list = ["\n\nCities:: 1) Jaipur 2) Kota 3) Mumbai 4) Delhi 5) Bengluru 6) Pune 7) Gandhinagr(Gujrat) 8) Kolkata 9) Lucknow 10) Chennai 11) Agra 12) Chandigarh 13) Noida 14) Jodhpur 15) Bikaner 16) Surat"]
for i in cities_list:
    from colorama import Fore,Style
    print(Fore.MAGENTA,Style.BRIGHT+i,end=" ")

sel_city = input("\nSelect the city")    
if sel_city=="Jaipur" or sel_city=="Ahemdabad" or sel_city=="Mumbai" or sel_city=="Delhi" or sel_city=="Bengluru" or sel_city=="Pune" or sel_city=="Gandhinagr(Gujrat)" or sel_city=="chandigarh" or sel_city=="noida" or sel_city=="jodhpur" or sel_city=="bikaner":        
    print(Fore.GREEN,Style.BRIGHT+"\n\n \t\t\t\t\t Movies Available")
    movies = ["[1] Fukrey 3","[2] Chandramukhi 2","[3] The Nun 2","[4] Dream Girl 2","[5] Saw X"]
    print("\n")
    for i in movies:
        print(i)

    print("\n")
    select_movie = int(input("Enter the movie code you want to proceed with :"))
    if select_movie == 1:
        print(obj.fukrey())
    elif select_movie == 2:
        print(obj.chandramukhi())
    elif select_movie == 3:
        print(obj.nun())
    elif select_movie == 4:
        print(obj.dream_girl())
    elif select_movie == 5:
        print(obj.saw())
    else:
        print("Sorry! Movie is not available in your area")
        
elif sel_city=="Kota" or sel_city=="Kolkata" or sel_city=="Lucknow" or sel_city=="Chennai" or sel_city=="Agra" or sel_city=="ahemdabad":    
    print(Fore.GREEN,Style.BRIGHT+"\n\n \t\t\t\t\t Movies Available")
    movies=["[1] Dream Girl 2","[2] Gadar 2 The Katha Continues","[3] Fukrey 3","[4] The Nun 2","[5] Saw X"]
    print("\n")
    for i in movies:
        print(i)   
    print("\n")
    select_movie = int(input("Enter the movie code you want to proceed with :"))
    if select_movie == 1:
        print(obj.dream_girl())
    elif select_movie == 2:
        print(obj.gadar())
    elif select_movie == 3:
        print(obj.fukrey())
    elif select_movie == 4:
        print(obj.nun())
    elif select_movie == 5:
        print(obj.saw())
    else:
        print("Sorry! Movie is not available in your area")
# Out:
#  							      FUN CINEMA
#  						        www.funcinema_pvr.com
#  							   A PVR Experience
#
#
# Cities:: 1) Jaipur 2) Kota 3) Mumbai 4) Delhi 5) Bengluru 6) Pune 7) Gandhinagr(Gujrat) 8) Kolkata 9) Lucknow 10) Chennai 11) Agra 12) Chandigarh 13) Noida 14) Jodhpur 15) Bikaner 16) Surat
# Select the city Jaipur
#
#
#  					 Movies Available
#
#
# [1] Fukrey 3
# [2] Chandramukhi 2
# [3] The Nun 2
# [4] Dream Girl 2
# [5] Saw X
# Enter the movie code you want to proceed with : 3
# _________________________________________________________________________________________________________________________________
#
#
#  The Nun 2
#  ************
#
#  Ratings:  6.8/10 		  Votes:  51.2K Votes 		  2D, ICE, 4DX, MX4D, 2D SCREEN X 		  English, Hindi, Tamil, Telugu
#
#  1h 51m  •  Mystery, Thriller, Horror  •  A  •  7 Sep, 2023
#  ---------------------------------------------------------------
#  About the movie
#
# ...
